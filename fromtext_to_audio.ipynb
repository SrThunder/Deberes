# %% [markdown]
# <a href="https://colab.research.google.com/github/SrThunder/Deberes/blob/master/fromtext_to_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
# !pip install PyPDF2==3.0.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.6 MB/s eta 0:00:00
# ...

# %%
from gtts import gTTS
import os
from IPython import get_ipython
from IPython.display import display

# %%
from google.colab import files

# %%
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc1a1b15-8bec-4a46-947f-a259d628c86e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc1a1b15-8bec-4a46-947f-a259d628c86e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path = "my_pdf_file.pdf"

# %%
from IPython import get_ipython
from IPython.display import display
# !pip install gTTS PyPDF2==3.0.1
from gtts import gTTS
import os
import PyPDF2
from google.colab import files

def create_audiobook(file_path, output_file):
    if file_path.lower().endswith(".pdf"):
        with open(file_path, 'rb') as pdf_file:
            pdf_reader = PyPDF2.PdfReader(pdf_file)
            text = ""
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()
    else:
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()

    tts = gTTS(text=text, lang='en')
    tts.save(output_file)
    print(f"Audiobook saved as {output_file}")

# Upload the PDF file
uploaded = files.upload()

# Get the file path
file_path = list(uploaded.keys())[0]  # Assuming you uploaded only one file

# Create the audiobook
output_file = "audiobook.mp3"
create_audiobook(file_path, output_file)
os.system(f"start {output_file}")
# Out:
# ...
#      <input type="file" id="files-d45e8d45-1f34-41a8-9b8f-4d333aa57d84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d45e8d45-1f34-41a8-9b8f-4d333aa57d84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install SpeechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 44.7 MB/s eta 0:00:00
# ...

# %%
import speech_recognition as sr
from pydub import AudioSegment

# Load the audio file
audio = AudioSegment.from_mp3("audiobook.mp3")

# Create a recognizer instance
r = sr.Recognizer()

# Split the audio into chunks for transcription (adjust chunk size as needed)
chunk_size = 10 * 1000  # 10 seconds

for i in range(0, len(audio), chunk_size):
    chunk = audio[i:i + chunk_size]
    with sr.AudioFile(chunk.export(format="wav")) as source:
        audio_data = r.record(source)
        try:
            text = r.recognize_google(audio_data, language="en-US") # Assuming Spanish
            print(text)
        except sr.UnknownValueError:
            print("Could not understand audio")
        except sr.RequestError as e:
            print(f"Could not request results from Google Speech Recognition service; {e}")
# Out:
# what is Market Basket analysis Market Basket analysis in Python Isaiah Hall visiting associate professor of Finn
# buy Norwegian business school Market Basket analysis in Python selecting a bookstore layout Market Basket analysis in
# iPhone exploring transaction data Ted transaction one biography History Two Season three biography
# poetry four season history five thousand season poetry tid equals unique
# items purchased together Market Basket analysis
# python what is Market Basket analysis 1 identify products frequently purchased together biography and history
# fiction and poetry 2 construct recommendations based on these endings Place biography and history sections together
# Market Basket analysis in Python the use cases of Market Basket analysis 1
# build Netflix style recommendations engine to improve product recommendations on an e-commerce store 3 cross sell product
# for improve Inventory management 5 upsell products Market Basket analysis in pyth
# ...
